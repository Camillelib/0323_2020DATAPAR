# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests as r
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
# your code here
html=r.get(url).content
html
# Out:
# b'\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-FG+rXqMOivrAjdEQE7tO4BwM1poGmg70hJFTlNSxjX87grtrZ6UnPR8NkzwUHlQEGviu9XuRYeO8zH9YwvZhdg==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-146fab5ea30e8afac08dd11013bb4ee0.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-iXrV/b4ypc1nr10b3Giikqff+qAx5osQ0yJRxHRDd8mKFefdMtEZ0Sx
# ...

# %%
soup=BeautifulSoup(html)

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#css selector:h1.h3, p.f4.text-normal

# %%
table=soup.select('h1.h3, p.f4.text-normal')

# %%
text=[f"{i.text.strip()} {i['href']}" for i in soup.select('h1.h3>a')]
text
# Out:
# ['Jeremy Apthorp /nornagon',
#  'Jonah Williams /jonahwilliams',
#  'Felix Angelov /felangel',
#  'chencheng (云谦) /sorrycc',
#  'Sebastián Ramírez /tiangolo',
#  'Mariusz Nowak /medikoo',
#  'Dawid Urbaniak /Trancever',
#  'Jeffrey Su /JeffreySu',
#  'Hugo Bowne-Anderson /hugobowne',
#  'Felipe Fialho /felipefialho',
#  'Yuri Shkuro /yurishkuro',
#  'R.I.Pienaar /ripienaar',
#  'Zeno Rocha /zenorocha',
#  'Maxim Kulkin /maximkulkin',
#  'Robert Mosolgo /rmosolgo',
#  'Pierre Krieger /tomaka',
#  'Iman /imanghafoori1',
#  'Luis Alvarez D. /lfades',
#  'Matic Zavadlal /maticzav',
#  'Marten Seemann /marten-seemann',
#  'David Peter /sharkdp',
#  'Jake Wharton /JakeWharton',
#  'Jeff Bezanson /JeffBezanson',
#  'James Munnelly /munnerz',
#  'Matthew Johnson /mattjj']

# %%
#[i.text for i in table]

# %%
output=[name.text.strip().replace(' ','').replace('\n\n', ' ') for name in table]
[(output[i], output[i+1] )for i in range(0,len(output),2)]
# Out:
# [('JeremyApthorp', 'nornagon'),
#  ('JonahWilliams', 'jonahwilliams'),
#  ('FelixAngelov', 'felangel'),
#  ('chencheng(云谦)', 'sorrycc'),
#  ('SebastiánRamírez', 'tiangolo'),
#  ('MariuszNowak', 'medikoo'),
#  ('DawidUrbaniak', 'Trancever'),
#  ('JeffreySu', 'JeffreySu'),
#  ('HugoBowne-Anderson', 'hugobowne'),
#  ('FelipeFialho', 'felipefialho'),
#  ('YuriShkuro', 'yurishkuro'),
#  ('R.I.Pienaar', 'ripienaar'),
#  ('ZenoRocha', 'zenorocha'),
#  ('MaximKulkin', 'maximkulkin'),
#  ('RobertMosolgo', 'rmosolgo'),
#  ('PierreKrieger', 'tomaka'),
#  ('Iman', 'imanghafoori1'),
#  ('LuisAlvarezD.', 'lfades'),
#  ('MaticZavadlal', 'maticzav'),
#  ('MartenSeemann', 'marten-seemann'),
#  ('DavidPeter', 'sharkdp'),
#  ('JakeWharton', 'JakeWharton'),
#  ('JeffBezanson', 'JeffBezanson'),
#  ('JamesMunnelly', 'munnerz'),
#  ('MatthewJohnson', 'mattjj')]

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise

# %%
def BS(url, selector):
    html=r.get(url).content
    soup = BeautifulSoup(html)
    selection = soup.select(selector)
    return selection

# %%
url = 'https://github.com/trending/python?since=daily'
selector = 'h1.h3.lh-condensed a'

# %%
repos=BS('https://github.com/trending/python?since=daily', 'h1.h3.lh-condensed a' )

# %%
repos
# Out:
# [<a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_REPOSITORIES_PAGE","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":178549777,"originating_url":"https://github.com/trending/python?since=daily","user_id":null}}' data-hydro-click-hmac="31d775b4e3f50aee07e33e837855f0354b5d2dad5bdac439af680e9f75bb2ff5" href="/rojter-tech/pluradl.py">
#  <svg aria-hidden="true" class="octicon octicon-repo mr-1 text-gray" color="gray" height="16" mr="1" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#  <span class="text-normal">
#          rojter-tech /
#  </span>
#
#
#        pluradl.py
#  </a>,
# ...

# %%
output=[repo.text.strip().replace(' ','').replace('\n\n', ' ') for repo in repos]
output
# Out:
# ['rojter-tech/  pluradl.py',
#  'caoscott/  SReC',
#  '0voice/  interview_internal_reference',
#  'ageitgey/  face_recognition',
#  'manchenkoff/  skillbox-async-chat',
#  'XiaohangZhan/  deocclusion',
#  'google-research/  text-to-text-transfer-transformer',
#  'kon9chunkit/  GitHub-Chinese-Top-Charts',
#  'tiangolo/  fastapi',
#  'CorentinJ/  Real-Time-Voice-Cloning',
#  'home-assistant/  core',
#  'alex04072000/  ObstructionRemoval',
#  'pcomputo/  Whole-Foods-Delivery-Slot',
#  'CharlesPikachu/  Games',
#  'doccano/  doccano',
#  'google/  jax',
#  'hankcs/  HanLP',
#  'Sentdex/  pygta5',
#  'ray-project/  ray',
#  'Yelp/  elastalert',
#  'timgrossmann/  InstaPy',
#  'huggingface/  transformers',
#  'ikergarcia1996/  Self-Driving-Car-in-Video-Games',
#  'fizyr/  keras-retinanet',
#  'apache/  airflow']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'
html=r.get(url).content
soup=BeautifulSoup(html)

# %%
#[i['src'] for i in soup.select('img')]

# %%
# your code here
images = []
for img in soup.findAll('img'):
    images.append(img.get('src'))
images
# Out:
# ['//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
html=r.get(url).content
soup=BeautifulSoup(html)

# %%
#[i['href'] for i in soup.select('a')]

# %%
# your code here
links = []
for link in soup.findAll('a'):
    links.append(link.get('href'))
links
# Out:
# [None,
#  '#mw-head',
#  '#p-search',
#  'https://en.wiktionary.org/wiki/Python',
#  'https://en.wiktionary.org/wiki/python',
#  '#Snakes',
#  '#Ancient_Greece',
#  '#Media_and_entertainment',
#  '#Computing',
#  '#Engineering',
#  '#Roller_coasters',
#  '#Vehicles',
#  '#Weaponry',
#  '#People',
#  '#Other_uses',
#  '#See_also',
#  '/w/index.php?title=Python&action=edit&section=1',
#  '/wiki/Pythonidae',
#  '/wiki/Python_(genus)',
#  '/w/index.php?title=Python&action=edit&section=2',
#  '/wiki/Python_(mythology)',
#  '/wiki/Python_of_Aenus',
#  '/wiki/Python_(painter)',
#  '/wiki/Python_of_Byzantium',
#  '/wiki/Python_of_Catana',
#  '/w/index.php?title=Python&action=edit&section=3',
#  '/wiki/Python_(film)',
#  '/wiki/Pythons_2',
#  '/wiki/Monty_Python',
#  '/wiki/Python_(Monty)_Pictures',
#  '/w/index.php?title=Python&action=edit&section=4',
#  '/wiki/Python_(programming_language)',
#  '/wiki/CPython',
#  '/wiki/CMU_Common_Lisp',
#  '/wiki/PERQ#PERQ_3',
# ...

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
# your code here
us=BS(url, 'div.usctitlechanged')

# %%
output=[name.text.strip() for name in us]
len(output)
# Out:
# 4

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
# your code here
# css selector: h3
top10=BS(url, 'h3')
output=[name.text.strip() for name in top10]
output
# Out:
# ['YASER ABDEL SAID',
#  'ALEXIS FLORES',
#  'EUGENE PALMER',
#  'SANTIAGO VILLALBA MEDEROS',
#  'RAFAEL CARO-QUINTERO',
#  'ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'ARNOLDO JIMENEZ',
#  'JASON DEREK BROWN']

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'
selector='table'

# %%
table=BS(url, selector)
table[3]
# Out:
# <table border="0" cellpadding="0" cellspacing="0" width="100%"><thead>
# <tr>
# <td colspan="13" style="background: white;height: 1px"></td>
# </tr>
# ...

# %%
rows=table.find_all('tr')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-f715f97f7034> in <module>
# ----> 1 rows=table.find_all('tr')
#
# ~\Anaconda3\Anaconda33\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2079         """Raise a helpful exception to explain a common code fix."""
#    2080         raise AttributeError(
# -> 2081             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2082         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
[row.text.strip().split() for row in rows]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-1cc650da8aae> in <module>
# ----> 1 [row.text.strip().split() for row in rows]
#
# NameError: name 'rows' is not defined

# %%
table=[[cell.strip() for cell in row.text.strip().split('\n') if cell.strip()!=''] for row in rows]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-106fac550d06> in <module>
# ----> 1 table=[[cell.strip() for cell in row.text.strip().split('\n') if cell.strip()!=''] for row in rows]
#
# NameError: name 'rows' is not defined

# %%
#pd.DataFrame(table[1:], columns=table[0])

# %%
# Solution:
html = requests.get(url).content;
soup = BeautifulSoup(html);
earthquakes = soup.find('tbody').find_all("tr");

latest_earthquakes = [];
    
for earthquake in earthquakes[:20]:
    # Date and time
    date, time = earthquake.find('td', {'class': 'tabev6'}).find('a').text.split();
    # Latitude and longitude
    lat_deg, lon_deg = earthquake.find_all('td', {'class': 'tabev1'});
    lat_dir, lon_dir, magnitude = earthquake.find_all('td', {'class': 'tabev2'});
    lat_deg = f"{lat_deg.text.strip()} {lat_dir.text.strip()}";
    lon_deg = f"{lon_deg.text.strip()} {lon_dir.text.strip()}";
    # Region
    region = earthquake.find('td', {'class': 'tb_region'}).text.strip();
    # Create list of information and append
    earthquake_summary = [date, time, lat_deg , lon_deg, region];
    latest_earthquakes.append(earthquake_summary);
    
df = pd.DataFrame(latest_earthquakes, columns=['Date', 'Time', 'Latitude', 'Longitude', 'Region']);
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-bff662cda03c> in <module>
#       1 # Solution:
# ----> 2 html = requests.get(url).content;
#       3 soup = BeautifulSoup(html);
#       4 earthquakes = soup.find('tbody').find_all("tr");
#       5
#
# NameError: name 'requests' is not defined

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# solution
username = input('Please, input your username: ')
html = r.get(url + username).content;
soup = BeautifulSoup(html);

try:
    tweet_box = soup.find('li', {'class':'ProfileNav-item ProfileNav-item--tweets is-active'});
    tweets = tweet_box.find('a').find('span', {'class':'ProfileNav-value'});
    print("{} has {} number of tweets.".format(username, tweets.get('data-count')))
except:
    print('Account name not found...')
# Out:
# Please, input your username: hello
# hello has 1481 number of tweets.

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# solution
username = input('Please, input your username: ')
html = r.get(url + username).content;
soup = BeautifulSoup(html);

try:
    tweet_box = soup.find('li', {'class':'ProfileNav-item ProfileNav-item--followers'});
    tweets = tweet_box.find('a').find('span', {'class':'ProfileNav-value'});
    print("{} has {} followers.".format(username, tweets.get('data-count')))
except:
    print('Account name not found...')
# Out:
# Please, input your username: hello
# hello has 19213 followers.

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'
selector='a'
#class='link-box'

# %%
# your code here
wiki=BS(url, selector)

output=[i.text.strip() for i in wiki]
output
# Out:
# ['English\n6\xa0050\xa0000+ articles',
#  'Español\n1\xa0588\xa0000+ artículos',
#  '日本語\n1\xa0198\xa0000+ 記事',
#  'Deutsch\n2\xa0416\xa0000+ Artikel',
#  'Français\n2\xa0197\xa0000+ articles',
#  'Русский\n1\xa0611\xa0000+ статей',
#  'Italiano\n1\xa0595\xa0000+ voci',
#  '中文\n1\xa0109\xa0000+ 條目',
#  'Português\n1\xa0027\xa0000+ artigos',
#  'Polski\n1\xa0399\xa0000+ haseł',
#  'العربية',
#  'Deutsch',
#  'English',
#  'Español',
#  'Français',
#  'Italiano',
#  'Nederlands',
#  '日本語',
#  'Polski',
#  'Português',
#  'Русский',
#  'Sinugboanong Binisaya',
#  'Svenska',
#  'Українська',
#  'Tiếng Việt',
#  'Winaray',
#  '中文',
#  'Asturianu',
#  'Azərbaycanca',
#  'Български',
#  'Bân-lâm-gú / Hō-ló-oē',
#  'Беларуская',
#  'Català',
#  'Čeština',
#  'Dansk',
#  'Eesti',
#  'Ελληνικά',
#  'Esperanto',
#  'Euskara',
#  'فارسی',
#  'Galego',
#  'Հայերեն',
#  'हिन्दी',
#  'Hrvatski',
#  'Bahasa Indonesia',
#  'עברית',
#  'ქართული',
#  'Latina',
#  'Latviešu',
#  'Lietuvių',
# ...

# %%
# solution:
url = 'https://www.wikipedia.org/'
html = r.get(url).content;
soup = BeautifulSoup(html);

wikis = soup.find_all('a', {'class': 'link-box'});
for wiki in wikis:
    print(wiki.text.strip());
# Out:
# English
# 6 050 000+ articles
# Español
# 1 588 000+ artículos
# 日本語
# 1 198 000+ 記事
# Deutsch
# 2 416 000+ Artikel
# Français
# 2 197 000+ articles
# Русский
# 1 611 000+ статей
# Italiano
# 1 595 000+ voci
# 中文
# 1 109 000+ 條目
# Português
# 1 027 000+ artigos
# Polski
# 1 399 000+ haseł

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'
selector='h2'

# %%
# your code here
datasets= BS(url, selector)
output=[i.text.strip() for i in datasets]
output
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport']

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here
html=r.get(url).content
soup=BeautifulSoup(html)

# %%
#2 tables so selecting thanks to position in the page:
table=soup.select('table+h3+table+p+p+table')
table
# Out:
# [<table class="wikitable sortable">
#  <caption>Top languages by population per <i>Nationalencyklopedin</i>
#  </caption>
#  <tbody><tr>
#  <th>Rank
#  </th>
#  <th>Language
#  </th>
#  <th data-sort-type="number">Native<br/>speakers<br/>in millions<br/>2007 (2010)
#  </th>
#  <th>Percentage<br/>of world<br/>population<br/>(2007)
#  </th></tr>
#  <tr>
#  <td>1</td>
#  <td><b><a href="/wiki/Mandarin_Chinese" title="Mandarin Chinese">Mandarin</a></b> (entire branch)</td>
#  <td>935 (955)</td>
#  <td>14.1%
#  </td></tr>
#  <tr>
#  <td>2</td>
#  <td><b><a href="/wiki/Spanish_language" title="Spanish language">Spanish</a></b></td>
#  <td>390 (405)</td>
#  <td>5.85%
#  </td></tr>
#  <tr>
#  <td>3</td>
#  <td><b><a href="/wiki/English_language" title="English language">English</a></b></td>
#  <td>365 (360)</td>
#  <td>5.52%
#  </td></tr>
#  <tr>
#  <td>4</td>
# ...

# %%
table=soup.find_all('table', {'class':'wikitable sortable'})[0]
rows=table.find_all('tr')
[row.text.strip().split() for row in rows]
table=[[cell.strip() for cell in row.text.strip().split('\n') if cell.strip()!=''] for row in rows]
table
# Out:
# [['Rank',
#   'Language',
#   'Speakers(millions)',
#   '% of the World population',
#   '(March 2019)[8]',
#   'Language familyBranch'],
#  ['1', 'Mandarin Chinese', '918', '11.922', 'Sino-TibetanSinitic'],
#  ['2', 'Spanish', '480', '5.994', 'Indo-EuropeanRomance'],
#  ['3', 'English', '379', '4.922', 'Indo-EuropeanGermanic'],
#  ['4',
#   'Hindi (Sanskritised Hindustani)[9]',
#   '341',
#   '4.429',
#   'Indo-EuropeanIndo-Aryan'],
#  ['5', 'Bengali', '228', '2.961', 'Indo-EuropeanIndo-Aryan'],
#  ['6', 'Portuguese', '221', '2.870', 'Indo-EuropeanRomance'],
#  ['7', 'Russian', '154', '2.000', 'Indo-EuropeanBalto-Slavic'],
#  ['8', 'Japanese', '128', '1.662', 'JaponicJapanese'],
#  ['9', 'Western Punjabi[10]', '92.7', '1.204', 'Indo-EuropeanIndo-Aryan'],
#  ['10', 'Marathi', '83.1', '1.079', 'Indo-EuropeanIndo-Aryan'],
#  ['11', 'Telugu', '82.0', '1.065', 'DravidianSouth-Central'],
#  ['12', 'Wu Chinese', '81.4', '1.057', 'Sino-TibetanSinitic'],
# ...

# %%
df=pd.DataFrame(table[0:], columns=table[0])
df
# Out:
#     Rank                            Language  Speakers(millions)  \
# 0   Rank                            Language  Speakers(millions)
# 1      1                    Mandarin Chinese                 918
# 2      2                             Spanish                 480
# 3      3                             English                 379
# 4      4  Hindi (Sanskritised Hindustani)[9]                 341
# ..   ...                                 ...                 ...
# 87    87                               Czech                10.7
# 88    88                Taʽizzi-Adeni Arabic                10.5
# 89    89                              Uyghur                10.4
# 90    90                    Min Dong Chinese                10.3
# 91    91                             Sylheti                10.3
#
#     % of the World population            (March 2019)[8]  \
# 0   % of the World population            (March 2019)[8]
# 1                      11.922        Sino-TibetanSinitic
# ...

# %%
df['Language'].head(11)
# Out:
# 0                               Language
# 1                       Mandarin Chinese
# 2                                Spanish
# 3                                English
# 4     Hindi (Sanskritised Hindustani)[9]
# 5                                Bengali
# 6                             Portuguese
# 7                                Russian
# 8                               Japanese
# 9                    Western Punjabi[10]
# 10                               Marathi
# Name: Language, dtype: object

# %%
# trying to convert the table into a pd.df

#not working 

#from IPython.display import display_html
#display_html(table, raw=True)

# %%
# !pip install lxml

# %%
# example to convert but not working
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'http://my-trade.in/'
page = requests.get(url)

soup = BeautifulSoup(page.content, 'html.parser')

tbl = soup.find("table",{"id":"MainContent_dataGridView1"})

data_frame = pd.read_html(str(tbl))[0];

# %%
#solution
html = r.get(url).content
soup = BeautifulSoup(html)
languages = soup.find('table', {'class': 'wikitable sortable'}).find_all('a', attrs = {'title' : True});

for i in range(10):
    print(languages[i].text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-9891792ae4f5> in <module>
#       2 html = r.get(url).content
#       3 soup = BeautifulSoup(html)
# ----> 4 languages = soup.find('table', {'class': 'wikitable sortable'}).find_all('a', attrs = {'title' : True});
#       5
#       6 for i in range(10):
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# solution

html = requests.get(url).content;
soup = BeautifulSoup(html);

movies = soup.find_all('td', {'class':'titleColumn'})
titles = [movie.find('a').text for movie in movies]
years = [movie.find('span').text[1:-1] for movie in movies]
directors = [movie.find('a').get('title').split(',')[0][:-7] for movie in movies]
actors = [' & '.join(movie.find('a').get('title').split(',')[1:]) for movie in movies]

movies_dict = {'Title': titles, 'Release': years, 'Director': directors, 'Actors': actors}

movies_df = pd.DataFrame(movies_dict)
movies_df
# Out:
#                                   Title Release              Director  \
# 0                            Les évadés    1994        Frank Darabont
# 1                            Le parrain    1972  Francis Ford Coppola
# 2               Le parrain, 2ème partie    1974  Francis Ford Coppola
# 3    The Dark Knight: Le chevalier noir    2008     Christopher Nolan
# 4                Douze hommes en colère    1957          Sidney Lumet
# ..                                  ...     ...                   ...
# 245                                P.K.    2014       Rajkumar Hirani
# 246                             Aladdin    1992          Ron Clements
# 247                   L'enfer est à lui    1949           Raoul Walsh
# 248                        Winter Sleep    2014     Nuri Bilge Ceylan
# 249            Le château de l'araignée    1957        Akira Kurosawa
#
#                                Actors
# 0       Tim Robbins &  Morgan Freeman
# 1          Marlon Brando &  Al Pacino
# ...

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here
#PREVIOUS SOLUTION TRANSFORMED

import numpy as np

html = requests.get(url).content;
soup = BeautifulSoup(html);

movies = soup.find_all('td', {'class':'titleColumn'})
titles = [movie.find('a').text for movie in movies]
years = [movie.find('span').text[1:-1] for movie in movies]
#directors = [movie.find('a').get('title').split(',')[0][:-7] for movie in movies]
#actors = [' & '.join(movie.find('a').get('title').split(',')[1:]) for movie in movies]

movies_dict = {'Title': titles, 'Release': years}

movies_df = pd.DataFrame(movies_dict)
movies_df.iloc[np.random.choice(np.arange(len(movies_df)), 10, False)]
# Out:
#                                        Title Release
# 200                      Luke la main froide    1967
# 160                             Elephant Man    1980
# 20                           La Cité de Dieu    2002
# 14   Le seigneur des anneaux: Les deux tours    2002
# 88               2001, l'odyssée de l'espace    1968
# 190                 The Grand Budapest hotel    2014
# 65                        Princesse Mononoké    1997
# 69                         Avengers: Endgame    2019
# 19                                     Seven    1995
# 121                Monty Python, sacré Graal    1975

# %%
links_to_movies = [movie.find('a').get('href') for movie in movies[0:n_random]]

# %%
# solution

from random import shuffle;

n_random = 10;

html = requests.get(url).content;
soup = BeautifulSoup(html);
movies = soup.find_all('td', {'class':'titleColumn'})

shuffle(movies)

titles = [movie.find('a').text for movie in movies[0:n_random]]
years = [movie.find('span').text[1:-1] for movie in movies[0:n_random]]
links_to_movies = [movie.find('a').get('href') for movie in movies[0:n_random]]

summary = []
for link in links_to_movies:
    html = requests.get('https://www.imdb.com' + link).content;
    soup = BeautifulSoup(html);
    summary.append(soup.find('div', {'class':'summary_text'}).text.strip());

movies_dict = {'Title': titles, 'Release': years, 'Summary': summary}

movies_df = pd.DataFrame(movies_dict)
movies_df
# Out:
#                            Title Release  \
# 0                   Pulp Fiction    1994
# 1                       3 Idiots    2009
# 2                Amours chiennes    2000
# 3  Monty Python: La Vie de Brian    1979
# 4           Inglourious Basterds    2009
# 5                   Barry Lyndon    1975
# 6         Le loup de Wall Street    2013
# 7                La Cité de Dieu    2002
# 8        Le parrain, 2ème partie    1974
# 9                        Aladdin    1992
#
#                                              Summary
# 0  The lives of two mob hitmen, a boxer, a gangst...
# 1  Two friends are searching for their long lost ...
# 2  A horrific car accident connects three stories...
# 3  Born on the original Christmas in the stable n...
# 4  In Nazi-occupied France during World War II, a...
# 5  An Irish rogue wins the heart of a rich widow ...
# 6  Based on the true story of Jordan Belfort, fro...
# 7  In the slums of Rio, two kids' paths diverge a...
# ...

# %%
# Adapting to my solution

import numpy as np

html = r.get(url).content;
soup = BeautifulSoup(html);

movies = soup.find_all('td', {'class':'titleColumn'})
titles = [movie.find('a').text for movie in movies]
years = [movie.find('span').text[1:-1] for movie in movies]
links_to_movies = [movie.find('a').get('href') for movie in movies]

summary = []
for link in links_to_movies:
    html = r.get('https://www.imdb.com' + link).content;
    soup = BeautifulSoup(html);
    summary.append(soup.find('div', {'class':'summary_text'}).text.strip());

movies_dict = {'Title': titles, 'Release': years, 'Summary': summary}

movies_df = pd.DataFrame(movies_dict)
movies_df.iloc[np.random.choice(np.arange(len(movies_df)), 10, False)]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-57ec6e4d88f5> in <module>
#      13 summary = []
#      14 for link in links_to_movies:
# ---> 15     html = r.get('https://www.imdb.com' + link).content;
#      16     soup = BeautifulSoup(html);
#      17     summary.append(soup.find('div', {'class':'summary_text'}).text.strip());
#
# ~\Anaconda3\Anaconda33\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\Anaconda33\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
# ...

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'
# Out:
# Enter the city: denver

# %%
# solution:

weather_json = requests.get(url).json()

print("\n{}'s temperature: {}°C ".format(city.capitalize(), weather_json['main']['temp']))
print("Wind speed: {} m/s".format(weather_json['wind']['speed']))
print("Description: {}".format(weather_json['weather'][0]['description'].capitalize()))
print("Weather: {}".format(weather_json['weather'][0]['main'].capitalize()))
# Out:
# Denver's temperature: 0.62°C
# Wind speed: 2.6 m/s
# Description: Few clouds
# Weather: Clouds

# %%
weather_json
# Out:
# {'coord': {'lon': -104.98, 'lat': 39.74},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 0.62,
#   'feels_like': -3.39,
#   'temp_min': -2.78,
#   'temp_max': 3.33,
#   'pressure': 1020,
#   'humidity': 86},
#  'visibility': 16093,
#  'wind': {'speed': 2.6, 'deg': 280},
#  'clouds': {'all': 20},
#  'dt': 1586434804,
#  'sys': {'type': 1,
#   'id': 3449,
#   'country': 'US',
#   'sunrise': 1586435421,
#   'sunset': 1586482311},
#  'timezone': -21600,
#  'id': 5419384,
#  'name': 'Denver',
#  'cod': 200}

# %%
pd.DataFrame([weather_json])
# Out:
#                             coord  \
# 0  {'lon': -104.98, 'lat': 39.74}
#
#                                              weather      base  \
# 0  [{'id': 801, 'main': 'Clouds', 'description': ...  stations
#
#                                                 main  visibility  \
# 0  {'temp': 0.62, 'feels_like': -3.39, 'temp_min'...       16093
#
#                          wind       clouds          dt  \
# 0  {'speed': 2.6, 'deg': 280}  {'all': 20}  1586434804
#
#                                                  sys  timezone       id  \
# 0  {'type': 1, 'id': 3449, 'country': 'US', 'sunr...    -21600  5419384
#
#      name  cod
# 0  Denver  200

# %%
pd.DataFrame([weather_json]).T
# Out:
#                                                             0
# coord                          {'lon': -104.98, 'lat': 39.74}
# weather     [{'id': 801, 'main': 'Clouds', 'description': ...
# base                                                 stations
# main        {'temp': 0.62, 'feels_like': -3.39, 'temp_min'...
# visibility                                              16093
# wind                               {'speed': 2.6, 'deg': 280}
# clouds                                            {'all': 20}
# dt                                                 1586434804
# sys         {'type': 1, 'id': 3449, 'country': 'US', 'sunr...
# timezone                                               -21600
# id                                                    5419384
# name                                                   Denver
# cod                                                       200

# %%
df=pd.json_normalize(weather_json)
df
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 801, 'main': 'Clouds', 'description': ...  stations       16093
#
#            dt  timezone       id    name  cod  coord.lon  coord.lat  ...  \
# 0  1586434804    -21600  5419384  Denver  200    -104.98      39.74  ...
#
#    main.pressure  main.humidity  wind.speed  wind.deg  clouds.all  sys.type  \
# 0           1020             86         2.6       280          20         1
#
#    sys.id  sys.country  sys.sunrise  sys.sunset
# 0    3449           US   1586435421  1586482311
#
# [1 rows x 24 columns]

# %%
print(str(df['main.temp']))
print(df['wind.speed'])
print(df['weather'])
# Out:
# 0    0.62
# Name: main.temp, dtype: float64
# 0    2.6
# Name: wind.speed, dtype: float64
# 0    [{'id': 801, 'main': 'Clouds', 'description': ...
# Name: weather, dtype: object

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#selector:
#name: h3
#price: p class = product_price
#stock availability: p class = in stock availability

# %%
html = requests.get(url).content;
soup = BeautifulSoup(html)

# %%
books = soup.find_all('article', {'class': 'product_pod'})

titles = [book.find('h3').text for book in books];
prices = [book.find('p', {'class': 'price_color'}).text for book in books];
stock = [book.find('p', {'class': 'instock availability'}).text.strip() for book in books]

# %%
books
# Out:
# [<article class="product_pod">
#  <div class="image_container">
#  <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
#  </div>
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">£51.77</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
# ...

# %%
titles
# Out:
# ['A Light in the ...',
#  'Tipping the Velvet',
#  'Soumission',
#  'Sharp Objects',
#  'Sapiens: A Brief History ...',
#  'The Requiem Red',
#  'The Dirty Little Secrets ...',
#  'The Coming Woman: A ...',
#  'The Boys in the ...',
#  'The Black Maria',
#  'Starving Hearts (Triangular Trade ...',
#  "Shakespeare's Sonnets",
#  'Set Me Free',
#  "Scott Pilgrim's Precious Little ...",
#  'Rip it Up and ...',
#  'Our Band Could Be ...',
#  'Olio',
#  'Mesaerion: The Best Science ...',
#  'Libertarianism for Beginners',
#  "It's Only the Himalayas"]

# %%
books_dict = {'Title': titles, 'Price': prices, 'Stock': stock}

books_df = pd.DataFrame(books_dict)
books_df
# Out:
#                                     Title   Price     Stock
# 0                      A Light in the ...  £51.77  In stock
# 1                      Tipping the Velvet  £53.74  In stock
# 2                              Soumission  £50.10  In stock
# 3                           Sharp Objects  £47.82  In stock
# 4            Sapiens: A Brief History ...  £54.23  In stock
# 5                         The Requiem Red  £22.65  In stock
# 6            The Dirty Little Secrets ...  £33.34  In stock
# 7                 The Coming Woman: A ...  £17.93  In stock
# 8                     The Boys in the ...  £22.60  In stock
# 9                         The Black Maria  £52.15  In stock
# 10  Starving Hearts (Triangular Trade ...  £13.99  In stock
# 11                  Shakespeare's Sonnets  £20.66  In stock
# 12                            Set Me Free  £17.46  In stock
# 13    Scott Pilgrim's Precious Little ...  £52.29  In stock
# 14                      Rip it Up and ...  £35.02  In stock
# ...

# %%
# solution
html = requests.get(url).content;
soup = BeautifulSoup(html, "lxml");
books = soup.find_all('article', {'class': 'product_pod'})

titles = [book.find('h3').text for book in books];
prices = [book.find('p', {'class': 'price_color'}).text for book in books];
stock = [book.find('p', {'class': 'instock availability'}).text.strip() for book in books]

books_dict = {'Title': titles, 'Price': prices, 'Stock': stock}

books_df = pd.DataFrame(books_dict)
books_df
# Out:
#                                     Title   Price     Stock
# 0                      A Light in the ...  £51.77  In stock
# 1                      Tipping the Velvet  £53.74  In stock
# 2                              Soumission  £50.10  In stock
# 3                           Sharp Objects  £47.82  In stock
# 4            Sapiens: A Brief History ...  £54.23  In stock
# 5                         The Requiem Red  £22.65  In stock
# 6            The Dirty Little Secrets ...  £33.34  In stock
# 7                 The Coming Woman: A ...  £17.93  In stock
# 8                     The Boys in the ...  £22.60  In stock
# 9                         The Black Maria  £52.15  In stock
# 10  Starving Hearts (Triangular Trade ...  £13.99  In stock
# 11                  Shakespeare's Sonnets  £20.66  In stock
# 12                            Set Me Free  £17.46  In stock
# 13    Scott Pilgrim's Precious Little ...  £52.29  In stock
# 14                      Rip it Up and ...  £35.02  In stock
# ...
